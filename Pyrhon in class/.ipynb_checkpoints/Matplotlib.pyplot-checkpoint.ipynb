# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([1,2,3,4])
b=np.array([2,3,4,1])
plt.subplot(2,1,1)
plt.plot(a,b)
plt.title("plot1")
plt.show()

c=np.array([1,2,3,4])
d=np.array([1,2,3,4])
plt.subplot(2,1,2)
plt.plot(c,d)
plt.title("plot2")
plt.show()#-->for two different graph

plt.subplots_adjust(left=0.2,right=0.4,top=0.6,bottom=0.3)

# %%
#plt.plot(a,b,"o--b",ms=10)

# %%
c=np.array([1,2,3,4])
d=np.array([1,2,3,4])

# %%
plt.plot(c,d,"o--b")

# %% [markdown]
# # SCATTER PLOT

# %%
x=np.array([2,3,2,3,4,6,7,6,9])
y=np.array([8,7,6,5,9,3,2,1,4])
plt.subplot(2,1,1)
plt.scatter(x,y)
plt.title("plot1")
#plt.alpha(0.9)
x1=np.array([1,2,3,4,5,4,3,2,2])
x2=np.array([1,2,3,7,6,5,4,7,3])
plt.subplot(2,1,2)
plt.scatter(x1,x2)
plt.title("plot2")
# Out:
# Text(0.5, 1.0, 'plot2')

# %%
#plt.scatter(x,y,c="blue"
 # plt.subplot()       
#alpha=0.5 #for tranparency

# %% [markdown]
# # HISTOGRAM

# %%
x=[43,43,23,123,125,97,67,89,66,77,100,130
  ]

# %%
plt.hist(x,bins=3,rwidth=0.9)
# Out:
# (array([3., 4., 5.]),
#  array([ 23.        ,  58.66666667,  94.33333333, 130.        ]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# # Bar Graph

# %%
Company=["GOOGLE","AMAZON","APPLE","NETFLIX"]
Employee=[1100,2400,3400,6000]
Branch=[1000,2000,1400,1100]

index=np.arange(len(Company))
plt.xticks(index,Company)
plt.subplot(2,1,1)
plt.barh(Company,Employee,label="Employee")
plt.subplot(2,1,2)

plt.barh(Company,Branch,label="Branch",)


#plt.barh(Company,Employee)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       2 Employee=[1100,2400,3400,6000]
#       3 Branch=[1000,2000,1400,1100]
# ----> 5 index=np.arange(len(Company))
#       6 plt.xticks(index,Company)
#       7 plt.subplot(2,1,1)
#
# NameError: name 'np' is not defined

# %%
plt.barh(Company,Employee,height=0.8)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Pie Chart

# %%
Fruits=[111,232,2323,23232,2323]
mylabel=["Mango","Orange","Apple","Guava","Banana"]
plt.pie(Fruits,startangle=90,labels=mylabel,explode=[0.2,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1daaaa3e880>,
#   <matplotlib.patches.Wedge at 0x1daaaa3ebb0>,
#   <matplotlib.patches.Wedge at 0x1daaaa4c0d0>,
#   <matplotlib.patches.Wedge at 0x1daaaa4c5b0>,
#   <matplotlib.patches.Wedge at 0x1daaaa4ca60>],
#  [Text(-0.016063225070376566, 1.2999007549810635, 'Mango'),
#   Text(-0.05557008986878296, 1.0985954510701268, 'Orange'),
#   Text(-0.36160990840488, 1.0388639343741868, 'Apple'),
#   Text(0.041991180196531815, -1.0991982263384992, 'Guava'),
#   Text(0.281299047137158, 1.0634241139262017, 'Banana')])
